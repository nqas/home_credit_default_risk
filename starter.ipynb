# %% [markdown]
# <a href="https://colab.research.google.com/github/nqas/home_credit_default_risk/blob/main/starter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction

# %% [markdown]
# Please duplicate this file before conducting your own data exploration as conflicts can occur.
#
# Information on the dataset can be found here: https://www.kaggle.com/c/home-credit-default-risk
#
# ![](https://storage.googleapis.com/kaggle-media/competitions/home-credit/home_credit.png)

# %%
# Follow the instructions and paste the authorisation code when prompted
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
# %load_ext google.colab.data_table

# %%
# Load data from shared folder (takes about 1.5 minutes)
path = "/content/drive/My Drive/DM Project/home-credit-default-risk/"

filenames = ["sample_submission","previous_application","installments_payments",
"credit_card_balance","bureau_balance","bureau","application_train",
"application_test","POS_CASH_balance"]

for filename in filenames: vars()[filename] = pd.read_csv(path + filename + ".csv")
HomeCredit_columns_description = pd.read_csv(path + "HomeCredit_columns_description" + ".csv", engine='python')
# Out:
# The google.colab.data_table extension is already loaded. To reload it, use:
#   %reload_ext google.colab.data_table

# %%
HomeCredit_columns_description
# Out:
#      Unnamed: 0  ...                                Special
# 0             1  ...                                    NaN
# 1             2  ...                                    NaN
# 2             5  ...                                    NaN
# 3             6  ...                                    NaN
# 4             7  ...                                    NaN
# ..          ...  ...                                    ...
# 214         217  ...                                    NaN
# 215         218  ...  time only relative to the application
# 216         219  ...  time only relative to the application
# 217         220  ...                                    NaN
# 218         221  ...                                    NaN
#
# [219 rows x 5 columns]

# %% [markdown]
# # Application Train/Test

# %%
application_train.sample(20)
# Out:
#         SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 141247      263766       0         Cash loans           F            N
# 285217      430323       0         Cash loans           F            N
# 122263      241755       1         Cash loans           M            N
# 300308      447913       0         Cash loans           F            N
# 98538       214409       0    Revolving loans           M            Y
# 130109      250903       0         Cash loans           F            Y
# 220727      355702       0         Cash loans           F            N
# 118984      237969       0         Cash loans           M            Y
# 99909       215991       0         Cash loans           F            N
# 108270      225596       0         Cash loans           M            Y
# 65901       176414       0         Cash loans           F            N
# 223010      358310       0         Cash loans           F            N
# ...

# %% [markdown]
# # Bureau

# %%
bureau.sample(20)
# Out:
#          SK_ID_CURR  SK_ID_BUREAU CREDIT_ACTIVE CREDIT_CURRENCY  DAYS_CREDIT  \
# 1665395      188518       6651634        Active      currency 1         -666
# 837397       105771       6640560        Closed      currency 1         -250
# 889079       203128       5817303        Active      currency 1         -233
# 1184665      260194       5526864        Active      currency 1         -141
# 254120       186984       5839288        Active      currency 1          -32
# 880001       151822       6286584        Closed      currency 1         -890
# 255042       346337       5840418        Active      currency 1          -28
# 495708       188043       6441332        Active      currency 1        -1660
# 845259       250349       6275374        Closed      currency 1        -1603
# 1669998      144603       5602823        Closed      currency 1         -346
# 789151       309438       6500008        Active      currency 1        -1177
# ...

# %% [markdown]
# # Bureau Balance

# %%
bureau_balance.sample(20)
# Out:
#           SK_ID_BUREAU  MONTHS_BALANCE STATUS
# 2081812        5061426             -51      X
# 12523829       5879098             -12      C
# 7134039        5731751             -32      C
# 22251432       6326836             -68      C
# 2611879        5833532              -6      C
# 6389703        6025026              -6      C
# 2389079        6566251             -20      X
# 10531          5720142             -34      X
# 22007765       6206881             -20      0
# 10500452       6308650             -30      C
# 23817108       6737828             -28      C
# 2105489        6011152             -46      0
# 20193576       6820824             -96      C
# 14009847       6466779             -56      C
# 4662708        6801252             -92      C
# 27153177       6646608             -12      X
# 8987082        6093407             -25      X
# 14229382       6272595             -49      X
# 5625391        6037323             -54      0
# ...

# %% [markdown]
# # POS CASH Balance

# %%
POS_CASH_balance.sample(20)
# Out:
#          SK_ID_PREV  SK_ID_CURR  ...  SK_DPD  SK_DPD_DEF
# 2268647     1316555      449796  ...       0           0
# 3511415     2673146      237224  ...       0           0
# 8159894     2119673      197941  ...       0           0
# 2403578     2121060      292156  ...       0           0
# 564102      1460593      310029  ...       0           0
# 4862737     1589055      432192  ...       0           0
# 8851554     1441865      206328  ...       0           0
# 7658267     2271124      238364  ...       0           0
# 7359607     1938282      286577  ...       0           0
# 2081354     2391226      157288  ...       0           0
# 1993132     2795987      109010  ...       0           0
# 6123150     1656179      358322  ...       0           0
# 8122981     2295432      369845  ...       0           0
# 8953787     2644480      155215  ...       0           0
# 7507235     2127883      438697  ...       0           0
# ...

# %% [markdown]
# # Credit Card Balance

# %%
credit_card_balance.sample(20)
# Out:
#          SK_ID_PREV  SK_ID_CURR  ...  SK_DPD  SK_DPD_DEF
# 2816233     2403074      136963  ...       0           0
# 1406779     1499273      236077  ...       0           0
# 2957617     2366477      371309  ...       0           0
# 798152      2709164      263929  ...       0           0
# 290862      1311115      453888  ...       0           0
# 3074131     2664922      202739  ...       0           0
# 2673216     1951713      435371  ...       0           0
# 2881515     1969006      137137  ...       0           0
# 3300554     2592886      209784  ...       0           0
# 1250380     1386385      288261  ...       0           0
# 1756546     2110824      129974  ...       0           0
# 3105832     1488143      346810  ...       0           0
# 2550964     1317160      111178  ...       0           0
# 899707      2313973      371966  ...       0           0
# 864455      2623501      341795  ...       0           0
# ...

# %% [markdown]
# # Previous Application

# %%
previous_application.sample(20)
# Out:
#          SK_ID_PREV  SK_ID_CURR  ... DAYS_TERMINATION  NFLAG_INSURED_ON_APPROVAL
# 208810      2358568      147615  ...              NaN                        NaN
# 1525529     2008024      174634  ...           -778.0                        0.0
# 1057244     1315009      420610  ...         365243.0                        0.0
# 81017       1405460      402188  ...         365243.0                        0.0
# 775936      1368955      239179  ...           -935.0                        0.0
# 1463307     2276349      173139  ...              NaN                        NaN
# 251127      1111583      268801  ...           -457.0                        0.0
# 1585409     2187049      394748  ...              NaN                        NaN
# 54356       1288498      415449  ...         365243.0                        0.0
# 1498563     2817196      212606  ...          -1101.0                        0.0
# 1480799     2295373      168878  ...              NaN                        NaN
# ...

# %% [markdown]
# # Installments Payments

# %%
installments_payments.sample(20)
# Out:
#           SK_ID_PREV  SK_ID_CURR  ...  AMT_INSTALMENT  AMT_PAYMENT
# 2435707      1975291      130967  ...        1776.105     1776.105
# 6023733      2500248      290882  ...       14060.250    14060.250
# 6716855      2323138      208375  ...       20838.600    20838.600
# 4907131      1855480      276102  ...       18202.185    18202.185
# 179946       1231605      166211  ...       11048.535    11048.535
# 5077728      1155157      284871  ...       25481.745    25481.745
# 5354257      1052998      270375  ...      251872.290   251872.290
# 6852129      1830252      208115  ...       15998.940    15998.940
# 10090969     1596012      355948  ...        6750.000     6750.000
# 612640       1959374      156402  ...        3375.000     3375.000
# 5392135      1793041      261945  ...        2250.000     2250.000
# 7460537      1748696      213950  ...       18486.270    18486.270
# 13471745     2286212      445854  ...      560634.750   560634.750
# ...
